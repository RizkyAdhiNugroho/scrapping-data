# %% [markdown]
# #Bismillah Lancar

# %% [markdown]
# # Scrape Dataset dari Google Play

# %% [markdown]
# ##Tiket.com

# %%
# !pip install google-play-scraper
from google_play_scraper import app
import pandas as pd
import numpy as np
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#Konfigurasi dalam proses scrapping

from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.tiket.gits',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
    count=3000, # defaults to 100
    filter_score_with=None # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

#membuat dataframe 
df= pd.DataFrame(np.array(result),columns=['review'])
df= df.join(pd.DataFrame(df.pop('review').tolist()))

#Filter Date pada tanggal 27 sep (Hari pariwisata)
df1 = df[(df['at'] > '2021-09-27') & (df['at'] < '2022-09-27')]
df1
# Out:
#                                   reviewId               userName  \
# 1     2bcfb16b-69cd-4019-ab85-d2ea2d4dd5b8            Seo Hyeonjo
# 2     da2dfec8-2288-4a20-a9eb-ed9ac5a226da            Dandy Iswan
# 3     dd72d5eb-ab30-4277-bbd9-03993c222f3e          Hani Lukmanto
# 5     728da7cb-8b14-4124-88a1-082bb755b81f     Rinipuha Handayani
# 6     37799ca7-8074-49d1-8ffc-19a5d4eb198a         RICARD CASTELO
# ...                                    ...                    ...
# 2972  3314e918-81c6-4567-b03d-332778f04b41      Almair Dzaky Khan
# 2978  483de357-b91c-41ce-a934-210e05e70c05     wony eko apriyanto
# 2981  b6ff5b46-5c44-495f-8092-d3143c2865f0  Toriyansah Toriyansah
# 2989  4dfd277b-cab2-4fcb-9b24-849f944acb64      Joko sujatmiko ew
# 2991  e5adc499-1521-4c0d-a2af-722c3dc5a8bf                  Rob U
#
#                                               userImage  \
# 1     https://play-lh.googleusercontent.com/a-/ACNPE...
# 2     https://play-lh.googleusercontent.com/a/ALm5wu...
# ...

# %% [markdown]
# ##Traveloka

# %%
#Konfigurasi dalam proses scrapping

from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.traveloka.android',
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
    count=1200, # defaults to 100
    filter_score_with=None # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
)

#membuat dataframe 
df= pd.DataFrame(np.array(result),columns=['review'])
df= df.join(pd.DataFrame(df.pop('review').tolist()))

#Filter Date pada tanggal 27 sep (Hari pariwisata)
df2 = df[(df['at'] > '2021-09-27') & (df['at'] < '2022-09-27')]
df2
# Out:
#                                   reviewId              userName  \
# 0     cb6054ce-1de4-41a6-8840-994fec5d475c         Saya Rubiyana
# 2     68a5b415-f6d3-48d5-af41-0be854e345db            Samsiah Dj
# 3     0ed8da77-5c5a-4166-919f-e383b54e70da             dee hemry
# 4     c132bcdc-eaac-47d2-87d2-1436dc2ed260  Slamet Kabul Riyanto
# 7     e40d63da-f7e9-4956-9a59-646cc70e67ca                  Guh'
# ...                                    ...                   ...
# 1191  fb9771ef-976f-4f6e-8cb2-2bb7def313a6   Yudda Winanta Hadri
# 1192  11622a1a-3615-4307-9b49-17acd4c048dd             Arasyidms
# 1194  d6236f67-984b-4ab1-9fbf-3df4a0a2c7de          Teddy Yoseph
# 1197  85ddced5-d113-47d3-b974-95502717c274   Hartatik Prajayanti
# 1198  8a4b6ebe-e79d-4852-9d11-0bdd12c30f5c      suhartutik tutik
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a-/ACNPE...
# 2     https://play-lh.googleusercontent.com/a/ALm5wu...
# ...

# %%
df1 = df1[['userName', 'content', 'score', 'at']].copy()
df1
# Out:
#                    userName  \
# 1               Seo Hyeonjo
# 2               Dandy Iswan
# 3             Hani Lukmanto
# 5        Rinipuha Handayani
# 6            RICARD CASTELO
# ...                     ...
# 2972      Almair Dzaky Khan
# 2978     wony eko apriyanto
# 2981  Toriyansah Toriyansah
# 2989      Joko sujatmiko ew
# 2991                  Rob U
#
#                                                 content  score  \
# 1     Fitur nomor ponsel tidak bisa diubah, gimana k...      1
# 2     Aplikasinya kurang nyaman digunakan. Pesanan y...      1
# 3     1). Harga menginap di hotel yg saya pilih lebi...      1
# 5     Sangat kecewa, saya mau pesen tiket timnas vs ...      1
# 6     Sangat buruk, mengajukan payleter berbelit-bel...      1
# ...                                                 ...    ...
# 2972  Paket buat travelingnya juga donk, biar semaki...      5
# 2978  Beberapa pesan disini sangat puas..mudah cepat...      5
# ...

# %%
df2 = df[['userName', 'content', 'score', 'at']].copy()

# %%
df1.to_csv('tiket(clean).csv')
df2.to_csv('traveloka(clean).csv')
